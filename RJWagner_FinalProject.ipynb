# %%
import pandas as pd
otp=pd.read_csv("ontimepercent.csv")
filtered_otp = otp[(otp["mode"]=="Bus") & (otp["on_time_percent"] != 0)]
routeName = {}
filtered_otp.sort_values(by="route").head(20)
for index, row in filtered_otp.iterrows():
    if (row["route"]) not in route:
        routeName["route_name"] = row["route"]
# Out:
# {'route_name': 'Y49'}
# route_name

# %%
filtered_otp.sort_values(by="on_time_percent", ascending = False).tail(20)
# Out:
#           _id route                      route_name current_garage mode  \
# 2036  22012.0    67                67 - MONROEVILLE   East Liberty  Bus
# 2518  22520.0    67                67 - MONROEVILLE   East Liberty  Bus
# 543   20362.0     4                   4 - TROY HILL           Ross  Bus
# 127   19895.0    93  93 - LAWRENCEVILLE - HAZELWOOD   West Mifflin  Bus
# 368   20162.0    65              65 - SQUIRREL HILL   East Liberty  Bus
# 2409  22411.0    20                    20 - KENNEDY        Collier  Bus
# 1443  21367.0    15                    15 - CHARLES           Ross  Bus
# 66    19834.0    65              65 - SQUIRREL HILL   East Liberty  Bus
# 190   19958.0    15                    15 - CHARLES           Ross  Bus
# 254   20048.0    15                    15 - CHARLES           Ross  Bus
# 189   19957.0    15                    15 - CHARLES           Ross  Bus
# 1206  21104.0    15                    15 - CHARLES           Ross  Bus
# 968   20840.0    15                    15 - CHARLES           Ross  Bus
# 253   20047.0    15                    15 - CHARLES           Ross  Bus
# 492   20311.0    15                    15 - CHARLES           Ross  Bus
# 730   20576.0    15                    15 - CHARLES           Ross  Bus
# 1205  21103.0    15                    15 - CHARLES           Ross  Bus
# 493   20312.0    15                    15 - CHARLES           Ross  Bus
# 729   20575.0    15                    15 - CHARLES           Ross  Bus
# 967   20839.0    15                    15 - CHARLES           Ross  Bus
#
#      month_start  year_month day_type  on_time_percent data_source
# 2036      4/1/24    202404.0     SUN.           0.3380      Clever
# 2518      6/1/24    202406.0     SUN.           0.3366      Clever
# 543      10/1/23    202310.0     SUN.           0.3322      Clever
# 127       8/1/23    202308.0  WEEKDAY           0.3315      Clever
# 368       9/1/23    202309.0  WEEKDAY           0.3266      Clever
# 2409      6/1/24    202406.0     SAT.           0.3248      Clever
# 1443      2/1/24    202402.0     SAT.           0.3198      Clever
# 66        8/1/23    202308.0  WEEKDAY           0.3190      Clever
# 190       8/1/23    202308.0     SUN.           0.3110      Clever
# 254       9/1/23    202309.0     SUN.           0.2258      Clever
# 189       8/1/23    202308.0     SAT.           0.2065      Clever
# 1206      1/1/24    202401.0     SUN.           0.1700      Clever
# 968      12/1/23    202312.0     SUN.           0.1596      Clever
# 253       9/1/23    202309.0     SAT.           0.1572      Clever
# 492      10/1/23    202310.0     SAT.           0.1527      Clever
# 730      11/1/23    202311.0     SUN.           0.1415      Clever
# 1205      1/1/24    202401.0     SAT.           0.1384      Clever
# 493      10/1/23    202310.0     SUN.           0.1339      Clever
# 729      11/1/23    202311.0     SAT.           0.1205      Clever
# 967      12/1/23    202312.0     SAT.           0.0998      Clever
